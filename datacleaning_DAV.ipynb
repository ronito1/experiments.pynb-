# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(5,3), index=['a','c','e','f','h'],columns=['one', 'two','three'])
print(df)
df= df.reindex(['a','b','c','d','e','f','g','h'])
# Out:
#         one       two     three
# a  0.967309 -0.097801 -2.078760
# c  1.576828  0.690000 -0.874353
# e -2.102380 -0.940080 -1.253312
# f  0.717482 -1.776895  0.329132
# h  0.165290 -1.279421 -0.533835

# %% [markdown]
# # **Check for missing values**

# %%
print(df['one'])
df.isnull()
# Out:
# a    0.967309
# b         NaN
# c    1.576828
# d         NaN
# e   -2.102380
# f    0.717482
# g         NaN
# h    0.165290
# Name: one, dtype: float64
#      one    two  three
# a  False  False  False
# b   True   True   True
# c  False  False  False
# d   True   True   True
# e  False  False  False
# f  False  False  False
# g   True   True   True
# h  False  False  False

# %% [markdown]
# # **Replacing the missing values**

# %%
df= df.reindex(['a','b','c'])
print(df)
print("Nan replaced with '0' :")
# Out:
#         one       two     three
# a  0.967309 -0.097801 -2.078760
# b       NaN       NaN       NaN
# c  1.576828  0.690000 -0.874353
# Nan replaced with '0' :

# %% [markdown]
# ---

# %%
#2.Fill Na forward and backward

#  Method            Action
pad/fill         Fill methods forward
bfill/backfill   fill methods backward

# %%
df = pd.DataFrame(np.random.randn(5,3), index=['a','c','e','f','h'],columns=['one', 'two','three'])
print(df)
df= df.reindex(['a','b','c','d','e','f','g','h'])
print(df)
print(df.fillna(method='pad'))
# Out:
#         one       two     three
# a  1.445946 -1.713166  0.719552
# c -0.877671  1.113785  1.558576
# e -0.553245 -0.799796  0.074465
# f -1.656409 -0.995950  0.023352
# h -0.028009 -0.204646  0.956760
#         one       two     three
# a  1.445946 -1.713166  0.719552
# b       NaN       NaN       NaN
# c -0.877671  1.113785  1.558576
# d       NaN       NaN       NaN
# e -0.553245 -0.799796  0.074465
# f -1.656409 -0.995950  0.023352
# g       NaN       NaN       NaN
# h -0.028009 -0.204646  0.956760
#         one       two     three
# a  1.445946 -1.713166  0.719552
# b  1.445946 -1.713166  0.719552
# c -0.877671  1.113785  1.558576
# d -0.877671  1.113785  1.558576
# e -0.553245 -0.799796  0.074465
# f -1.656409 -0.995950  0.023352
# g -1.656409 -0.995950  0.023352
# h -0.028009 -0.204646  0.956760

# %%
df = pd.DataFrame(np.random.randn(5,3), index=['a','c','e','f','h'],columns=['one', 'two','three'])
print(df)
df= df.reindex(['a','b','c','d','e','f','g','h'])
print(df)
print(df.fillna(method='bfill'))
# Out:
#         one       two     three
# a  0.250238  0.430753 -0.958962
# c -1.374543  0.611223 -0.616399
# e -1.256489  1.877264  0.294968
# f -0.124463  1.492736  0.943426
# h  0.360795  1.373642  0.127837
#         one       two     three
# a  0.250238  0.430753 -0.958962
# b       NaN       NaN       NaN
# c -1.374543  0.611223 -0.616399
# d       NaN       NaN       NaN
# e -1.256489  1.877264  0.294968
# f -0.124463  1.492736  0.943426
# g       NaN       NaN       NaN
# h  0.360795  1.373642  0.127837
#         one       two     three
# a  0.250238  0.430753 -0.958962
# b -1.374543  0.611223 -0.616399
# c -1.374543  0.611223 -0.616399
# d -1.256489  1.877264  0.294968
# e -1.256489  1.877264  0.294968
# f -0.124463  1.492736  0.943426
# g  0.360795  1.373642  0.127837
# h  0.360795  1.373642  0.127837

# %%
df.dropna(axis=0)
# Out:
#         one       two     three
# a  1.445946 -1.713166  0.719552
# c -0.877671  1.113785  1.558576
# e -0.553245 -0.799796  0.074465
# f -1.656409 -0.995950  0.023352
# h -0.028009 -0.204646  0.956760
